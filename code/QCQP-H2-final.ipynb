# %%
using Revise, DynamicPolynomials, TSSOS, Random, LinearAlgebra,Statistics,LinearAlgebra,JLD2,StatsBase,Printf,IOLogging, SparseArrays,Arpack

include("C:/Users/Srecko/StrengtheningViaCDK/H2-QCQP/Functions-H2.jl")
# Out:
# indices (generic function with 1 method)

# %% [markdown]
# # RANDOM CASES, $s=0\%$

# %%
# dictionary to store all elements
data50_10_random = Dict(
    1 => selected_vec1,    
    2 => selected_vec2,     
    3 => selected_vec3,     
    4 => selected_vec4,     
    5 => selected_vec5,     
    6 => selected_vec6,     
    7 => first_50_differences   
)
# Out:
# Dict{Int64, Vector} with 7 entries:
#   5 => Any[[1.0, 1.0, 1.0, 1.0, 1.45694e-9, 1.0, 4.25401e-10, 1.38124e-9, 1.0, …
#   4 => Any[-11.3705, -16.4767, -6.14427, -10.2099, -18.153, -16.1808, -14.063, …
#   6 => Any[0.369593, 0.358756, 0.385533, 0.347728, 0.359006, 0.475825, 0.580313…
#   7 => [1, 2, 3, 5, 6, 7, 9, 10, 12, 14  …  53, 54, 55, 56, 57, 58, 59, 60, 61,…
#   2 => Any[[1.0, 1.0, 1.0, 1.0, -8.30165e-9, 1.0, -9.37943e-9, -9.37486e-9, 1.0…
#   3 => Any[-11.3705, -16.4767, -6.14427, -10.2099, -18.153, -16.1808, -14.063, …
#   1 => Any[-12.1588, -16.7469, -6.58292, -10.5131, -19.4004, -16.8376, -14.1739…

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/data50_10_random.jld2" data50_10_random

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_10_1pt5.jld2" res_10_1pt5

# %%
AnalyseResults(res_10_1pt5,data50_10_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [3.628619667908274, 0.23641359443512877]
#  [18.99759821760389, 4.82165790893491]
#  [0.021100380000000002, 0.30349348658]
#  [0, 44]
#  [Any[], Any[]]
#  [[10, 13, 38, 44], Any[14, 18, 50, 56], 4]

# %%
n=10
@polyvar x[1:n]
tau=1.1
seeds = data50_10_random[7]
solIpopt = data50_10_random[2];
res_10_1pt1 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=10_tau=1pt1.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-3.9647863501705096 -2.684397957760539 -2.0664126867973533 -1.368992719212943 -0.8677670424647933 0.41795692486063113 1.4018984078146088 2.021677687185407 2.4468514931090124 3.128936217841836]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -12.158800097527516
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# __________________ APPLYING THE HEURISTIC H2________________________________
#
# ___________ New total number of constraints: 16
#
#
# Summary: ____________________________________________________________________
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_10_1pt1.jld2" res_10_1pt1

# %%
AnalyseResults(res_10_1pt1,data50_10_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [3.628619667908274, 1.3606570432737646]
#  [18.99759821760389, 7.252118314929393]
#  [0.020608341999999998, 0.30349348658]
#  [0, 26]
#  [Any[], Any[]]
#  [[10, 13, 38, 44], Any[14, 18, 50, 56], 4]

# %% [markdown]
# ## $n=20$

# %%
@load "C:/Users/Srecko/StrengtheningViaCDK/Data/data50_20_random.jld2" data50_20_random
# Out:
# 1-element Vector{Symbol}:
#  :data50_20_random

# %% [markdown]
# ### $\tau=100$

# %%
n=20
@polyvar x[1:n]
tau=100
seeds = data50_20_random[7]
solIpopt = data50_20_random[2];
res_20_100 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=20_tau=100.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.73415956273971 -4.885550474109089 -4.54840365590392 -3.181356917028404 -2.518488416020887 -1.8731818447257724 -1.550963512476228 -0.8463092433019166 -0.33617911292336294 -0.2973054617266414 0.07485144663640111 1.392717543364462 1.6041029675242167 1.6741178840347415 2.517275568788407 2.9088506092153095 3.4386156884083747 4.584204587343776 5.550957133554807 6.727632925928681]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -40.124038673333644
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_100.jld2" res_20_100

# %%
AnalyseResults_H2(res_20_100,data50_20_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.833510860322637, 0.41032696045378914]
#  [16.178136185543863, 5.102133947239535]
#  [0.08312935217391304, 26.339082197130438]
#  [4, 39]
#  [Any[3, 11, 25, 38], Any[3, 11, 25, 38]]
#  [[3, 11, 18, 20, 25, 29, 32, 38], Any[3, 11, 18, 20, 25, 29, 32, 38], 8]

# %% [markdown]
# ### $\tau=1.5$

# %%
n=20
@polyvar x[1:n]
tau=1.5
seeds = data50_20_random[7]
solIpopt = data50_20_random[2];
res_20_1pt5 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=20_tau=1pt5.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.73415956273971 -4.885550474109089 -4.54840365590392 -3.181356917028404 -2.518488416020887 -1.8731818447257724 -1.550963512476228 -0.8463092433019166 -0.33617911292336294 -0.2973054617266414 0.07485144663640111 1.392717543364462 1.6041029675242167 1.6741178840347415 2.517275568788407 2.9088506092153095 3.4386156884083747 4.584204587343776 5.550957133554807 6.727632925928681]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -40.124038673333644
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_1pt5.jld2" res_20_1pt5

# %%
AnalyseResults_H2(res_20_1pt5,data50_20_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.833510860322637, 0.5883578710517439]
#  [16.178136185543863, 6.253055914295974]
#  [0.08636249130434782, 26.339082197130438]
#  [4, 35]
#  [Any[3, 11, 25, 38], Any[3, 11, 25, 38]]
#  [[3, 11, 18, 20, 25, 29, 32, 38], Any[3, 11, 18, 20, 25, 29, 32, 38], 8]

# %% [markdown]
# ### $\tau=1.25$

# %%
n=20
@polyvar x[1:n]
tau=1.25
seeds = data50_20_random[7]
solIpopt = data50_20_random[2];
res_20_1pt25 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=20_tau=1pt25.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.73415956273971 -4.885550474109089 -4.54840365590392 -3.181356917028404 -2.518488416020887 -1.8731818447257724 -1.550963512476228 -0.8463092433019166 -0.33617911292336294 -0.2973054617266414 0.07485144663640111 1.392717543364462 1.6041029675242167 1.6741178840347415 2.517275568788407 2.9088506092153095 3.4386156884083747 4.584204587343776 5.550957133554807 6.727632925928681]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -40.124038673333644
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_1pt25.jld2" res_20_1pt25

# %%
AnalyseResults_H2(res_20_1pt25,data50_20_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.932507104309495, 1.2122265069392295]
#  [16.178136185543863, 9.679552635030284]
#  [0.08531668775510204, 26.31052141369388]
#  [1, 28]
#  [Any[11], Any[11]]
#  [[3, 11, 18, 20, 25, 29, 32, 38], Any[3, 11, 18, 20, 25, 29, 32, 38], 8]

# %% [markdown]
# ### $\tau=1.1$

# %%
n=20
@polyvar x[1:n]
tau=1.1
seeds = data50_20_random[7]
solIpopt = data50_20_random[2];
res_20_1pt1 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=20_tau=1pt1.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.73415956273971 -4.885550474109089 -4.54840365590392 -3.181356917028404 -2.518488416020887 -1.8731818447257724 -1.550963512476228 -0.8463092433019166 -0.33617911292336294 -0.2973054617266414 0.07485144663640111 1.392717543364462 1.6041029675242167 1.6741178840347415 2.517275568788407 2.9088506092153095 3.4386156884083747 4.584204587343776 5.550957133554807 6.727632925928681]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -40.124038673333644
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_1pt1.jld2" res_20_1pt1

# %%
AnalyseResults_H2(res_20_1pt1,data50_20_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.933956594088055, 2.3139235226150534]
#  [16.178136185543863, 15.151716481379282]
#  [0.09360943799999999, 26.26763314656]
#  [0, 19]
#  [Any[], Any[]]
#  [[3, 11, 18, 20, 25, 29, 32, 38], Any[3, 11, 18, 20, 25, 29, 32, 38], 8]

# %% [markdown]
# ## $n=30$

# %%
@load "C:/Users/Srecko/StrengtheningViaCDK/Data/data50_30_random.jld2" data50_30_random
# Out:
# 1-element Vector{Symbol}:
#  :data50_30_random

# %% [markdown]
# ### $\tau=100$

# %%
n=30
@polyvar x[1:n]
tau=100
seeds = data50_30_random[7]
solIpopt = data50_30_random[2];
res_30_100 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=30_tau=100.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.534039771708519 -6.440912431982576 -6.126369162165736 -4.8128650194804345 -4.44546657745834 -3.5211490731754638 -3.0059022221542664 -2.9784399633849414 -2.4845776799448327 -2.254583423635901 -1.7481146333016437 -1.512988100664734 -0.6343760613570022 -0.49274159733297673 0.2548812027995528 0.710181149257967 1.1995871664073974 1.520134521286682 1.7922091304788597 2.0066662595347 2.407639875269815 2.689151238943239 3.258992742938401 3.6029453187648586 4.128986011102476 4.331436790335791 4.723179347246815 5.4700111873997574 6.506456819368324 7.639853659323537]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -74.89135156333985
#
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_100.jld2" res_30_100

# %%
AnalyseResults_H2(res_30_100,data50_30_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [5.092011926917466, 0.5250281176480991]
#  [16.60051407476731, 5.2991250711791364]
#  [0.3043397102564102, 1209.9830905963076]
#  [11, 32]
#  [Any[3, 4, 5, 10, 13, 20, 23, 27, 35, 39, 41], Any[3, 4, 5, 10, 13, 20, 23, 27, 35, 39, 41]]
#  [[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], Any[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], 15]

# %% [markdown]
# ### $\tau=1.5$

# %%
n=30
@polyvar x[1:n]
tau=1.5
seeds = data50_30_random[7]
solIpopt = data50_30_random[2];
res_30_1pt5 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=30_tau=1pt5.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.534039771708519 -6.440912431982576 -6.126369162165736 -4.8128650194804345 -4.44546657745834 -3.5211490731754638 -3.0059022221542664 -2.9784399633849414 -2.4845776799448327 -2.254583423635901 -1.7481146333016437 -1.512988100664734 -0.6343760613570022 -0.49274159733297673 0.2548812027995528 0.710181149257967 1.1995871664073974 1.520134521286682 1.7922091304788597 2.0066662595347 2.407639875269815 2.689151238943239 3.258992742938401 3.6029453187648586 4.128986011102476 4.331436790335791 4.723179347246815 5.4700111873997574 6.506456819368324 7.639853659323537]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -74.89135156333985
#
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_1pt5.jld2" res_30_1pt5

# %%
AnalyseResults_H2(res_30_1pt5,data50_30_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [5.452555618259327, 0.7572109946785183]
#  [16.60051407476731, 6.166996804265592]
#  [0.29556008181818183, 1202.4574483467047]
#  [6, 27]
#  [Any[3, 5, 20, 23, 35, 39], Any[3, 5, 20, 23, 35, 39]]
#  [[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], Any[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], 15]

# %%
n=30
@polyvar x[1:n]
tau=1.25
seeds = data50_30_random[7]
solIpopt = data50_30_random[2];
res_30_1pt25 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=30_tau=1pt25.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.534039771708519 -6.440912431982576 -6.126369162165736 -4.8128650194804345 -4.44546657745834 -3.5211490731754638 -3.0059022221542664 -2.9784399633849414 -2.4845776799448327 -2.254583423635901 -1.7481146333016437 -1.512988100664734 -0.6343760613570022 -0.49274159733297673 0.2548812027995528 0.710181149257967 1.1995871664073974 1.520134521286682 1.7922091304788597 2.0066662595347 2.407639875269815 2.689151238943239 3.258992742938401 3.6029453187648586 4.128986011102476 4.331436790335791 4.723179347246815 5.4700111873997574 6.506456819368324 7.639853659323537]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -74.89135156333985
#
#
#
# ...

# %% [markdown]
# ### $\tau=1.25$

# %%
n=30
@polyvar x[1:n]
tau=1.25
seeds = data50_30_random[7]
solIpopt = data50_30_random[2];
res_30_1pt25 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=30_tau=1pt25.txt",true)

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_1pt25.jld2" res_30_1pt25

# %%
AnalyseResults_H2(res_30_1pt25,data50_30_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [5.565598849831683, 1.4838634088902949]
#  [16.60051407476731, 6.947589750102592]
#  [0.30612403043478265, 1203.9104392193042]
#  [4, 18]
#  [Any[5, 20, 23, 39], Any[5, 20, 23, 39]]
#  [[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], Any[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], 15]

# %% [markdown]
# ### $\tau=1.1$

# %%
n=30
@polyvar x[1:n]
tau=1.1
seeds = data50_30_random[7]
solIpopt = data50_30_random[2];
res_30_1pt1 = Run_H2_Multiple_Instances(x, n, seeds, solIpopt, tau, "n=30_tau=1pt1.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.534039771708519 -6.440912431982576 -6.126369162165736 -4.8128650194804345 -4.44546657745834 -3.5211490731754638 -3.0059022221542664 -2.9784399633849414 -2.4845776799448327 -2.254583423635901 -1.7481146333016437 -1.512988100664734 -0.6343760613570022 -0.49274159733297673 0.2548812027995528 0.710181149257967 1.1995871664073974 1.520134521286682 1.7922091304788597 2.0066662595347 2.407639875269815 2.689151238943239 3.258992742938401 3.6029453187648586 4.128986011102476 4.331436790335791 4.723179347246815 5.4700111873997574 6.506456819368324 7.639853659323537]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -74.89135156333985
#
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_1pt1.jld2" res_30_1pt1

# %%
AnalyseResults_H2(res_30_1pt1,data50_30_random)
# Out:
# 6-element Vector{Vector{Any}}:
#  [5.526652877739973, 2.7811069995344404]
#  [16.60051407476731, 11.229341406801137]
#  [0.32292837916666667, 1207.3915041780208]
#  [2, 11]
#  [Any[5, 39], Any[5, 39]]
#  [[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], Any[3, 4, 5, 10, 13, 15, 18, 19, 20, 23, 27, 32, 35, 39, 41], 15]

# %% [markdown]
# # RANDOM CASES, $s=20\%$

# %% [markdown]
# ## $n=20$

# %%
@load "C:/Users/Srecko/StrengtheningViaCDK/Data/data50_20_rsparse.jld2" data50_20_rsparse
# Out:
# 1-element Vector{Symbol}:
#  :data50_20_rsparse

# %%
data50_20_rsparse
# Out:
# Dict{Int64, Vector{Any}} with 7 entries:
#   5 => [[1.0, 1.0, 1.0, 1.0, 6.93531e-10, 1.0, 1.0, 1.90217e-9, 4.1187e-9, 1.0,…
#   4 => [-44.3235, -38.3999, -30.6052, -39.4842, -30.1263, -34.4208, -21.2788, -…
#   6 => [26.1295, 26.5583, 26.1467, 24.2762, 24.132, 26.4442, 24.4396, 28.6642, …
#   7 => [1, 2, 4, 5, 6, 7, 8, 10, 11, 12  …  43, 44, 45, 46, 47, 48, 49, 50, 51,…
#   2 => [[1.0, 1.0, 1.0, 1.0, -9.61972e-9, 1.0, 1.0, -9.29825e-9, -9.53533e-9, 1…
#   3 => [-44.3235, -38.3999, -30.6052, -39.4842, -29.9054, -34.4208, -21.2788, -…
#   1 => [-44.6656, -39.7603, -31.5871, -40.1257, -31.9767, -34.5951, -23.1069, -…

# %% [markdown]
# ### $\tau=100$

# %%
n=20
@polyvar x[1:n]
percentage_dense=0.8
tau=100
seeds = data50_20_rsparse[7]
solIpopt = data50_20_rsparse[2];
res_20_100_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=20_tau=100_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.155595270967006 -4.1976567792794155 -3.7781937843500155 -2.994781843885475 -2.765158846379 -2.205820020951261 -1.6793957048850428 -1.2100111765984916 -0.38374137665890545 -0.3270656510195488 -0.07066265323764738 0.8247689512271008 0.8750753758397052 1.6093759909376948 1.6730899846977163 2.031898151609844 2.707791507793095 3.427621904685814 3.8584133963687366 6.031234963673126]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -44.66557836622809
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_100_rsparse.jld2" res_20_100_rsparse

# %%
AnalyseResults_H2(res_20_100_rsparse,data50_20_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.317297814371383, 0.26793670112305096]
#  [18.274508826127516, 5.589390543924781]
#  [0.02644942093023256, 26.79262271195349]
#  [7, 38]
#  [Any[5, 13, 16, 19, 32, 41, 50], Any[6, 15, 18, 21, 34, 43, 52]]
#  [[5, 13, 16, 17, 19, 27, 32, 41, 43, 45, 46, 50], Any[6, 15, 18, 19, 21, 29, 34, 43, 45, 47, 48, 52], 12]

# %% [markdown]
# ### $\tau=1.5$

# %%
n=20
@polyvar x[1:n]
percentage_dense=0.8
tau=1.5
seeds = data50_20_rsparse[7]
solIpopt = data50_20_rsparse[2];
res_20_1pt5_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=20_tau=1pt5_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.155595270967006 -4.1976567792794155 -3.7781937843500155 -2.994781843885475 -2.765158846379 -2.205820020951261 -1.6793957048850428 -1.2100111765984916 -0.38374137665890545 -0.3270656510195488 -0.07066265323764738 0.8247689512271008 0.8750753758397052 1.6093759909376948 1.6730899846977163 2.031898151609844 2.707791507793095 3.427621904685814 3.8584133963687366 6.031234963673126]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -44.66557836622809
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_1pt5_rsparse.jld2" res_20_1pt5_rsparse

# %%
AnalyseResults_H2(res_20_1pt5_rsparse,data50_20_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.394652066385068, 0.39141704281439377]
#  [18.274508826127516, 6.225211271741529]
#  [0.04499331555555556, 26.734133816644448]
#  [5, 36]
#  [Any[16, 19, 32, 41, 50], Any[18, 21, 34, 43, 52]]
#  [[5, 13, 16, 17, 19, 27, 32, 41, 43, 45, 46, 50], Any[6, 15, 18, 19, 21, 29, 34, 43, 45, 47, 48, 52], 12]

# %% [markdown]
# ### $\tau=1.25$

# %%
n=20
@polyvar x[1:n]
percentage_dense=0.8
tau=1.25
seeds = data50_20_rsparse[7]
solIpopt = data50_20_rsparse[2];
res_20_1pt25_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=20_tau=1pt25_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.155595270967006 -4.1976567792794155 -3.7781937843500155 -2.994781843885475 -2.765158846379 -2.205820020951261 -1.6793957048850428 -1.2100111765984916 -0.38374137665890545 -0.3270656510195488 -0.07066265323764738 0.8247689512271008 0.8750753758397052 1.6093759909376948 1.6730899846977163 2.031898151609844 2.707791507793095 3.427621904685814 3.8584133963687366 6.031234963673126]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -44.66557836622809
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_1pt25_rsparse.jld2" res_20_1pt25_rsparse

# %%
AnalyseResults_H2(res_20_1pt25_rsparse,data50_20_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.739977023100486, 0.8778422995090239]
#  [18.274508826127516, 10.914632042144468]
#  [0.043784275510204085, 26.5596402462653]
#  [1, 29]
#  [Any[16], Any[18]]
#  [[5, 13, 16, 17, 19, 27, 32, 41, 43, 45, 46, 50], Any[6, 15, 18, 19, 21, 29, 34, 43, 45, 47, 48, 52], 12]

# %% [markdown]
# ### $\tau=1.1$

# %%
n=20
@polyvar x[1:n]
percentage_dense=0.8
tau=1.1
seeds = data50_20_rsparse[7]
solIpopt = data50_20_rsparse[2];
res_20_1pt1_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=20_tau=1pt1_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-5.155595270967006 -4.1976567792794155 -3.7781937843500155 -2.994781843885475 -2.765158846379 -2.205820020951261 -1.6793957048850428 -1.2100111765984916 -0.38374137665890545 -0.3270656510195488 -0.07066265323764738 0.8247689512271008 0.8750753758397052 1.6093759909376948 1.6730899846977163 2.031898151609844 2.707791507793095 3.427621904685814 3.8584133963687366 6.031234963673126]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -44.66557836622809
#
#
#
#  _________________******_________________******_________________********_________________
#  _________________******_________________******_________________********_________________
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_20_1pt1_rsparse.jld2" res_20_1pt1_rsparse

# %%
AnalyseResults_H2(res_20_1pt1_rsparse,data50_20_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [4.739977023100486, 2.1773743073517235]
#  [18.274508826127516, 16.74144579608213]
#  [0.04453045714285716, 26.5596402462653]
#  [1, 17]
#  [Any[16], Any[18]]
#  [[5, 13, 16, 17, 19, 27, 32, 41, 43, 45, 46, 50], Any[6, 15, 18, 19, 21, 29, 34, 43, 45, 47, 48, 52], 12]

# %% [markdown]
# ## $n=30$

# %%
@load "C:/Users/Srecko/StrengtheningViaCDK/Data/data50_30_rsparse.jld2" data50_30_rsparse
# Out:
# 1-element Vector{Symbol}:
#  :data50_30_rsparse

# %% [markdown]
# ### $\tau=100$

# %%
n=30
@polyvar x[1:n]
percentage_dense=0.8
tau=100
seeds = data50_30_rsparse[7]
solIpopt = data50_30_rsparse[2];
res_30_100_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=30_tau=100_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.519522893156305 -5.7500083472014865 -4.81702627422449 -4.499588701719986 -4.128545719735633 -3.5836760646132553 -3.332503067673116 -2.7223655902032995 -2.6651640600670174 -2.3613138703517293 -1.9150345289098576 -1.2684191751030556 -0.9598203238806741 -0.8372200223024185 -0.06230439517861438 0.13455798618007847 0.40501446132391533 0.8232212349925008 0.9276454723050509 1.358606962051771 1.6390449899038184 1.7937080736172457 2.5805884242380324 3.1196972942973917 3.2153124965224973 4.058714780108679 4.567300895552234 4.924357558412646 5.045462686633467 6.145323603430272]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -63.52570736566878
#
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_100_rsparse.jld2" res_30_100_rsparse

# %%
AnalyseResults_H2(res_30_100_rsparse,data50_30_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [6.058624700288842, 0.7404593354549673]
#  [13.487250847612783, 6.332693333269966]
#  [0.09449529999999998, 1172.473025378178]
#  [5, 30]
#  [Any[1, 7, 29, 46, 48], Any[1, 7, 29, 46, 48]]
#  [[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], Any[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], 21]

# %% [markdown]
# ### $\tau=1.5$

# %%
n=30
@polyvar x[1:n]
percentage_dense=0.8
tau=1.5
seeds = data50_30_rsparse[7]
solIpopt = data50_30_rsparse[2];
res_30_1pt5_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=30_tau=1pt5_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.519522893156305 -5.7500083472014865 -4.81702627422449 -4.499588701719986 -4.128545719735633 -3.5836760646132553 -3.332503067673116 -2.7223655902032995 -2.6651640600670174 -2.3613138703517293 -1.9150345289098576 -1.2684191751030556 -0.9598203238806741 -0.8372200223024185 -0.06230439517861438 0.13455798618007847 0.40501446132391533 0.8232212349925008 0.9276454723050509 1.358606962051771 1.6390449899038184 1.7937080736172457 2.5805884242380324 3.1196972942973917 3.2153124965224973 4.058714780108679 4.567300895552234 4.924357558412646 5.045462686633467 6.145323603430272]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -63.52570736566878
#
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_1pt5_rsparse.jld2" res_30_1pt5_rsparse

# %%
AnalyseResults_H2(res_30_1pt5_rsparse,data50_30_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [6.030057574491436, 1.0218919379993354]
#  [13.487250847612783, 7.2227254085570625]
#  [0.08671024583333331, 1167.3442309975835]
#  [2, 29]
#  [Any[1, 46], Any[1, 46]]
#  [[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], Any[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], 21]

# %% [markdown]
# ### $\tau=1.25$

# %%
n=30
@polyvar x[1:n]
percentage_dense=0.8
tau=1.25
seeds = data50_30_rsparse[7]
solIpopt = data50_30_rsparse[2];
res_30_1pt25_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=30_tau=1pt25_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.519522893156305 -5.7500083472014865 -4.81702627422449 -4.499588701719986 -4.128545719735633 -3.5836760646132553 -3.332503067673116 -2.7223655902032995 -2.6651640600670174 -2.3613138703517293 -1.9150345289098576 -1.2684191751030556 -0.9598203238806741 -0.8372200223024185 -0.06230439517861438 0.13455798618007847 0.40501446132391533 0.8232212349925008 0.9276454723050509 1.358606962051771 1.6390449899038184 1.7937080736172457 2.5805884242380324 3.1196972942973917 3.2153124965224973 4.058714780108679 4.567300895552234 4.924357558412646 5.045462686633467 6.145323603430272]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -63.52570736566878
#
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_1pt25_rsparse.jld2" res_30_1pt25_rsparse

# %%
AnalyseResults_H2(res_30_1pt25_rsparse,data50_30_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [6.058775213267766, 1.7797058049415022]
#  [13.487250847612783, 7.999748107051978]
#  [0.092528896, 1163.1338995285398]
#  [0, 12]
#  [Any[], Any[]]
#  [[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], Any[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], 21]

# %% [markdown]
# ### $\tau=1.1$

# %%
n=30
@polyvar x[1:n]
percentage_dense=0.8
tau=1.1
seeds = data50_30_rsparse[7]
solIpopt = data50_30_rsparse[2];
res_30_1pt1_rsparse = Run_H2_Multiple_Instances_rsparse(x, n, seeds, percentage_dense, solIpopt, tau, "n=30_tau=1pt1_rsparse.txt",true)
# Out:
# ()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()()
# ()()()()()______________ SOLVING THE INSTANCE 1 _______________()()()()()
#
# _______________ INITIAL PROBLEM CHARACTERISTICS_____________________
#
# Eigvals of Q = [-6.519522893156305 -5.7500083472014865 -4.81702627422449 -4.499588701719986 -4.128545719735633 -3.5836760646132553 -3.332503067673116 -2.7223655902032995 -2.6651640600670174 -2.3613138703517293 -1.9150345289098576 -1.2684191751030556 -0.9598203238806741 -0.8372200223024185 -0.06230439517861438 0.13455798618007847 0.40501446132391533 0.8232212349925008 0.9276454723050509 1.358606962051771 1.6390449899038184 1.7937080736172457 2.5805884242380324 3.1196972942973917 3.2153124965224973 4.058714780108679 4.567300895552234 4.924357558412646 5.045462686633467 6.145323603430272]
#
#
#
# _______________ SOLVING THE INITIAL RELAXATION _____________________
#
#
#
# INITIAL BOUND = -63.52570736566878
#
#
#
# ...

# %%
@save "C:/Users/Srecko/StrengtheningViaCDK/Data/res_30_1pt1_rsparse.jld2" res_30_1pt1_rsparse

# %%
AnalyseResults_H2(res_30_1pt1_rsparse,data50_30_rsparse)
# Out:
# 6-element Vector{Vector{Any}}:
#  [6.058775213267766, 3.3637288459328816]
#  [13.487250847612783, 11.617976756839859]
#  [0.09174291600000001, 1163.1338995285398]
#  [0, 5]
#  [Any[], Any[]]
#  [[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], Any[1, 2, 3, 4, 5, 6, 7, 8, 20, 23  …  29, 30, 35, 37, 39, 40, 46, 48, 49, 50], 21]
